# %%
import numpy as np
from collections import OrderedDict
import random as rm

file  = open('HP_output_data_files/final_output_HPn20.txt',"r")
file1 = open("HP_output_data_files/HP_20_possible_new_unique_str_count_prob.txt","w")
file2 = open("HP_output_data_files/HP_20_possible_new_unique_str.txt","w")
file3 = open("HP_output_data_files/HP_20_possible_new_unique_str_prob.txt","w")

arr = file.read()
arr_t = arr.split("\n")
arr_t.pop()

print(arr_t)

str_size = 20  # size of the string
col_1 = []
col_2 = []
col_3 = []

#temp = arr_t[0]
#print(len(temp))
#print(arr_t[0])
#print("Printed")


for i in range (0,len(arr_t)):
    temp= arr_t[i]
    temp1 = temp[0:str_size]
    col_1.append(temp1)
    temp2 = temp[str_size+1:2*str_size]
    col_2.append(temp2)
    temp3 = temp[2*str_size+1:]
    col_3.append(temp3)

len_in_out = len(col_1) 
print("Reading and splitting done")
print("sample ", col_1[0], col_2[0], col_3[0])
print("Inputs")
print("---------------------------------")
print(col_1)
print("---------------------------------")
print("Outputs")
print("---------------------------------")
print(col_2)
print("---------------------------------")
print("frequency")
print("---------------------------------")
print(col_3)
print("---------------------------------")

#print("col_2_unique printed") 
#print("---------------------------------")
#col_2_unique=list(OrderedDict.fromkeys(col_2))    
#print(col_2_unique)
#print("---------------------------------")
#print("col_3_unique printed above")
#print("---------------------------------")
#counter = 0
#col_3_unique = []
#for i in range(0,len(col_2_unique)):
#    counter = 0
#    w = col_2_unique[i]
#    for j in range(0,len(col_2)):
#        m = col_2[j]
#        if w == m:
#            counter = counter + 1
#    col_3_unique.append(counter)
#print(col_3_unique)
#print("---------------------------------")

selected_str = 'URRDRDLDLDLULLURRRU'
target_strs = []

for j in range(0,len(col_2)):
    if selected_str == col_2[j]:
        target_strs.append(col_1[j])

print("For selected string",selected_str)        
print("I am new col 1")
print(target_strs)
print("---------------------------------")

new_col_1 = []

for i in range(0,len(target_strs)):   #
    x = target_strs[i]
    index = 0
    for j in range(0,len(x)):
        temp = list(x)
        if x[index] == "H":
            temp[index] = "P"
            x1 = "".join(temp)
            new_col_1.append(x1)
        else:
            temp[index] = "H"
            x1 = "".join(temp)
            new_col_1.append(x1)
        index = index + 1

    new_col_2 = []
    for k in range(0,len(new_col_1)):
        p = new_col_1[k]
#    print("p in iteration k=",k, "is",p)
        count = 0
        for l in range(0,len(col_1)):
            q = col_1[l]
#        print("q in iteration k=",k, "and l = ",l, "is",q)
            if p == q:
                count = count +1
#            print('index of matching is',l)
                w = col_2[l]
                new_col_2.append(w)
#            print(p, "is mapped on to ",col_2[l])
        if count == 0:
            new_col_2.append("AAAAAAAAAAAAAAAAAAAA")
#            print(p, "is mapped on to Null")
#        print('total count is',count)
print("new inputs outputs done")
print("New_inputs")
print("---------------------------------")
print(new_col_1)
print(len(new_col_1))
print("---------------------------------")
print("new_outputs")
print("---------------------------------")
print(new_col_2)
print(len(new_col_2))
print("---------------------------------") 

arrlist = np.array(new_col_2) 
unique, counts = np.unique(arrlist, return_counts=True)
w = dict(zip(unique, counts))
#print(w)
#print("-----------------------------")

total_outputs = 0
for kv in w.items():
    total_outputs = total_outputs+kv[1]
#print("Total output is",total_outputs)

for kv in w.items():
    file1.write(selected_str)
    file1.write("\t")
    file1.write(str(kv[0]))
    file2.write(str(kv[0]))
    file1.write("\t")
    file1.write(str(kv[1]))
    file1.write('\t')
    file1.write(str(kv[1]/total_outputs))
    file3.write(str(kv[1]/total_outputs))
    file1.write("\n")
    file2.write("\n")
    file3.write("\n")

print("Bingo")


file.close()
file1.close()
file2.close()
file3.close()

#t2 = toc()

#print(t2)
# Out:
# ['PHHHPPHHHPPPPPHHPPHP UUUURDDDDDLLUUULURU 1', 'PHHHPPHHHPPPPPHPPPHH UUUURDDDDDLLUULUURD 2', 'PHHHPPHHHPPPPPHPHPHH UUUURDDDDDLLUULUURD 2', 'HHHHPPHHHHHHPHHPHPPH UUUURDDDRUURDDDLDLU 1', 'HHHHPPHHHPPHPPPHPPHH UUUURDDDRDLDLLULURU 1', 'HHHHPPHHHHPHHPHPPHHH UUUURDDRURDDDLDLUUR 2', 'HHHHPPHHHHPHHHHPPHHH UUUURDDRURDDDLDLUUR 2', 'HHHHPPHHHHPHHHHHPPHH UUUURDDRURDDLLDDRUR 1', 'HHHHPPHHHHHHPPHPHHPH UUUURDDRDLDDRURUUUL 1', 'PHHPPPPHPPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHHPPPHPPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHPPPHHPPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHHPPHHPPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHHHPHHPPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHPPPPHHPHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHPPPPHPHHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHHPPPHPHHPPPPPHPPH UUUURDDRDLDDLLUULUR 17', 'PHHPPPPHPPHPPPHPHPPH UUUURDDRDLDDLLUULUR 17', 'HHHPPPPHPPHHPPPHHPPH UUUURDDRDLDDLLUULUR 17', 'HHHHPPPHPPHHPPPHHPPH UUUURDDRDLDDLLUULUR 17', 'HHHPPPPHPHHHPPPHHPPH UUUURDDRDLDDLLUULUR 17', 'HHHPPPPHPPHHPHPHHP
# ...
