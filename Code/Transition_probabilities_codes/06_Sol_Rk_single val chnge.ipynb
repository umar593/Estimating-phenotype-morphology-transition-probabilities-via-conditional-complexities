# %%
import numpy as np
from math import sqrt
import random as rm
import matplotlib.pyplot as plt

# Initializing files and arrays
file1 = open("parameters_str374_050.txt", "w")
file2 = open("solution_str374_050.txt", "w")
file3 = open("parameters_output.txt", "r")

arr = file3.read()
arr_parm_list = arr.split("\n")
arr_parm_list.pop()

print(len(arr_parm_list))
print(arr_parm_list)

def rhs(u, p, t):
    f0= p[0]*u[2]      - p[2]*u[0]*u[5]
    f1= p[1]*u[3]      - p[3]*u[1]*u[5]
    f2= p[2]*u[0]*u[5] - p[0]*u[2] 
    f3= p[3]*u[1]*u[5] - p[1]*u[3]
    f4= p[6]*u[2]      + p[5]*u[0]     - p[9]*u[4]
    f5= p[13]*u[4]     + p[0]*u[2]     + p[1]*u[3]- u[5]*(p[2]*u[0]+p[3]*u[1]+p[4]*u[7]+p[11])
    f6= p[8]*u[3]      + p[7]*u[1]     - p[10]*u[6]
    f7= p[14]*u[6]     - p[4]*u[5]*u[7]+ p[11]*u[8]-p[12]*u[7]
    f8= p[4]*u[5]*u[7] - p[11]*u[8]
    return np.array([f0, f1, f2, f3, f4, f5, f6, f7, f8])

def rk4(f, u0, p, t0, tf , n):
    t = np.linspace(t0, tf, n+1)
    u = np.array((n+1)*[u0])
    #print(u)
    h = t[1]-t[0]
    for i in range(n):
        k1 = h * f(u[i], p, t[i])    
        k2 = h * f(u[i] + 0.5 * k1, p, t[i] + 0.5*h)
        k3 = h * f(u[i] + 0.5 * k2, p, t[i] + 0.5*h)
        k4 = h * f(u[i] + k3, p, t[i] + h)
        u[i+1] = u[i] + (k1 + 2*(k2 + k3 ) + k4) / 6
    return u, t

# for loop 2nd argument >>>>>> len(arr_parm_list)

for w in range(0,50):
    for k in range(0,15):
        u = np.array([1., 1., 0. , 0., 0., 0., 0., 0., 0.])
        p = np.array([50.0, 100.0, 1.0, 1.0, 2.0, 50, 500, 0.01, 50, 10, 0.5, 1, 0.2, 50, 5])
        prob = np.linspace(0.25, 2.0, 8) 
        
        #for_index = np.linspace(1, 43, 15)
        counter = 1
        arr_new = []
        ww = list(arr_parm_list[w])
        for s in range(0,len(ww)):
            if counter == s:
                arr_new.append(int(ww[s]))
                counter = counter + 3
        
        index = rm.randint(0,7)
#        print('ranadom number index ',index,'for k =',k)
              
#        print(arr_new)
 #       print(prob)
 #       print(p)
        if k == 0:
            file1.write(str(arr_new)+'\n')
        arr_new[k] = index
#        print(arr_new)

        file1.write(str(arr_new)+'\n')
    
        for e in range (0,15):
            p[e] = p[e]*prob[int(arr_new[e])]
#        print(p)
#        print("------------------------")
        file1.write(str(p)+'\n')    

#    print(p)
#    file1.write(str(p)+'\n')
#-----------------------------------    
        u, t = rk4(rhs, u, p, 0., 10.0, 500000)
#    e1, e2, e3, e4, e5, e6, e7, e8, e9 = u.T
#    print(len(u))
        for j in range(1,500000):
            if j % 25000 == 0:
                file2.write(str(u[j][8])+'\n')
#                print(j,'----------',u[j][8])
        print(u[500000][8])
        print("Done with string",w," paramter number ", k)
#        plt.figure(1)
#        ax = plt.gca()
#        ax.grid(True)
#    np.linspace(0,10,200000)
#        plt.plot(t,u)
#        plt.xlabel(" time")
#        plt.ylabel("Concentration")
#        plt.legend(["Da","Dr","Da'","Dr'","Ma","A","Mr","R","C"])
#        plt.show()
file1.close()
file2.close()
file3.close()
# Out:
# 21
# ['[2, 5, 2, 6, 0, 4, 1, 7, 6, 4, 5, 6, 4, 1, 4]', '[0, 0, 6, 5, 0, 1, 0, 3, 4, 7, 2, 7, 5, 2, 1]', '[4, 0, 1, 6, 0, 0, 1, 6, 4, 1, 5, 7, 4, 0, 2]', '[0, 2, 4, 1, 5, 6, 2, 2, 6, 2, 6, 7, 7, 1, 7]', '[0, 0, 3, 6, 5, 3, 1, 0, 6, 4, 4, 6, 7, 3, 4]', '[0, 0, 3, 4, 1, 2, 1, 6, 6, 5, 2, 7, 7, 0, 0]', '[7, 5, 2, 6, 0, 3, 3, 2, 7, 6, 7, 7, 6, 4, 7]', '[6, 6, 6, 4, 1, 1, 0, 6, 6, 6, 6, 6, 7, 7, 5]', '[0, 0, 7, 4, 7, 3, 0, 1, 7, 6, 7, 7, 2, 3, 1]', '[0, 2, 5, 3, 1, 0, 0, 6, 5, 2, 5, 6, 7, 2, 7]', '[2, 5, 3, 4, 5, 3, 0, 5, 3, 4, 7, 7, 5, 3, 7]', '[2, 3, 5, 5, 1, 5, 1, 7, 3, 7, 6, 6, 5, 1, 3]', '[5, 3, 4, 1, 2, 6, 1, 6, 6, 7, 7, 6, 7, 7, 7]', '[6, 6, 4, 5, 5, 6, 1, 6, 7, 7, 6, 7, 7, 2, 2]', '[0, 1, 2, 6, 1, 1, 4, 7, 7, 7, 6, 7, 5, 2, 4]', '[5, 0, 3, 7, 4, 4, 1, 1, 7, 6, 7, 4, 6, 0, 1]', '[2, 6, 1, 6, 0, 4, 0, 6, 4, 7, 5, 7, 6, 5, 5]', '[5, 6, 1, 5, 1, 3, 1, 6, 7, 6, 7, 7, 6, 4, 3]', '[4, 3, 5, 5, 0, 5, 1, 5, 7, 6, 4, 7, 7, 0, 1]', '[5, 1, 6, 3, 0, 6, 2, 6, 6, 6, 5, 7, 3, 2, 4]', '[3, 1, 2, 3, 1, 2, 0, 4, 1, 3, 4, 7, 6, 2, 7]']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-850857cae15e> in <module>
#      80 #    file1.write(str(p)+'\n')
#      81 #-----------------------------------
# ---> 82         u, t = rk4(rhs, u, p, 0., 10.0, 500000)
#      83 #    e1, e2, e3, e4, e5, e6, e7, e8, e9 = u.T
#      84 #    print(len(u))
#
# <ipython-input-1-850857cae15e> in rk4(f, u0, p, t0, tf, n)
#      36         k1 = h * f(u[i], p, t[i])
#      37         k2 = h * f(u[i] + 0.5 * k1, p, t[i] + 0.5*h)
# ---> 38         k3 = h * f(u[i] + 0.5 * k2, p, t[i] + 0.5*h)
#      39         k4 = h * f(u[i] + k3, p, t[i] + h)
#      40         u[i+1] = u[i] + (k1 + 2*(k2 + k3 ) + k4) / 6
#
# <ipython-input-1-850857cae15e> in rhs(u, p, t)
#      25     f6= p[8]*u[3]      + p[7]*u[1]     - p[10]*u[6]
#      26     f7= p[14]*u[6]     - p[4]*u[5]*u[7]+ p[11]*u[8]-p[12]*u[7]
# ---> 27     f8= p[4]*u[5]*u[7] - p[11]*u[8]
#      28     return np.array([f0, f1, f2, f3, f4, f5, f6, f7, f8])
#      29
#
# KeyboardInterrupt:
